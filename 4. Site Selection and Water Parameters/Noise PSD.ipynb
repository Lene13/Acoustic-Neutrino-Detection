# %% [markdown]
# # Noise Power Spectrum Density

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Sources:
#
# * [1] https://pdf.sciencedirectassets.com/314898/1-s2.0-S1474667016X60508/1-s2.0-S1474667016351217/main.pdf?X-Amz-Security-Token=IQoJb3JpZ2luX2VjECMaCXVzLWVhc3QtMSJIMEYCIQD4%2FDKjx7yTk6vqTArYtk0GJ6texSNyxWHYx2%2FFiVAJ3wIhAK9vQ6QzNmmpDIF3npuHhUZTpucOmuXmxKY8eVr7f%2BmdKrMFCCwQBRoMMDU5MDAzNTQ2ODY1Igw7E6PV60ohwUqLUEoqkAXG7xWTDByiyGDWipuIy0lVm%2FnR5oTDTEAk25YPg0dYyKdXogpOsKewpoXbinJtA5T6%2FIlEXLXlVpbXvaw2%2Fxpd7gDQeApNZHo1P4hz9Mo7S8cm5NJ%2B3F2Ggx7F%2FmUuEVAfdMaB9fuhvLiGGqOG%2FaMFkSxhz%2BbV%2FS%2FFAqfQOLe1jTlDb1ZwshIUoS865RaFWqAmd30DtZ3KODBD02cnFxLtFH%2B5jKGvsITP04S02YpEewr9gpilEQ4fRf%2BoVBnxZXajFuRU4fZ6iSyF9z47F5WLgMYiCwqmAKsEgSqemnN3Btg1%2FqjW14JKHw2I2xUl%2FY9X7Q4vGDh8tm03ItCPQzo%2FMybaGtE4Ojbpu51AhRoqojIxrxSx9GtqMliEwAftN7Qi6ZjfA7zT9iDnjiOrh2PNTMa2wZJMcj%2F2S0C2sMl8nIYnY1vcxFe5SkjRtf%2BgjaoMEhWFAK%2BAzNQ9jBZevsL8t2CpVjdFA3OGrWOtVzJIJNUWgNwhRLjqX6frvkEEteHWMQRVg052RihZoCl66yBLaVscWFH9YPWLGBUukL%2F%2FkEKgZT4qw6osV90h3iqyE6G68jXb%2BHQ9o64g7gXnUkDbDbTUZWhCMzFzvzneGmE50ET6heB9%2Borj%2BE0u7%2B82qyeFf9o6%2Fp%2BtHcTw0K7aNNL2NKiHbBY24PiU%2FemLai3QWTnNi86AFjMmv8Nd97gHE3PSvknTcjIC8w6JYyxRFZZNYQawjzP54yMbFh%2BVTjAKb2CexKYtPyYkHL5X79FtvyXRvbHPSTXRp7Et3knDsccpzeWZkZgdqFj1Pd%2BlM0cAseMrUctYYws7YJ4auol0r4qqTd2y025jUkZRsSjAqNKtl1mqEuM2xZv0Kqzy8TGHmTDTt7uvBjqwAZFmNLDYZeKMyArRAAblyUohbw0lMAKtOaP6zdS95Pf5Dky7Rfdfy9aYY5yhCoSLGWIAfW9s%2FABvddX7pDhNsSAPLFGqtNDwAGaX4DS0M6WL3vMIxDN8rTGMhdKkShyslWU6di4Qw3wZy6G7i28ByDKHpd2zwow9fkSsxpiJRilewQMHhVcWQSOKUBu6Tgu44eTr6%2BUHgFET%2F3tPril1ApD4T%2BrpCF9hBCo5fBVFH03M&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20240311T112157Z&X-Amz-SignedHeaders=host&X-Amz-Expires=300&X-Amz-Credential=ASIAQ3PHCVTYXVE7ZIEQ%2F20240311%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=3910cf0a55febaee75b0925ed22c4559c5ee712ed3bc8cc162d5d33ca1f3d515&hash=bc16fd11a346434a26bf872f212f9e3092b80a32dd33f47da0d43cff9f32677a&host=68042c943591013ac2b2430a89b270f6af2c76d8dfd086a07176afe7c76c2c61&pii=S1474667016351217&tid=spdf-56654e37-e4bb-4451-9e7c-9fb51081cc8a&sid=057dcd9c5022a644494be24-a5a4b93cf520gxrqb&type=client&tsoh=d3d3LnNjaWVuY2VkaXJlY3QuY29t&ua=140e5a525d02515a0053&rr=862b29f429596728&cc=nl
#
# * [2] https://www.researchgate.net/publication/224599959_Variability_of_available_capacity_due_to_the_effects_of_depth_and_temperature_in_the_underwater_acoustic_communication_channel
#
# * [3] https://books.google.nl/books?id=M_kIAQAAIAAJ&ots=KXw7GlRqcv&dq=Urick%2C%20R.J.%20(1983).%20Principles%20of%20Underwater%20Sound.%20Peninsula%20Publishing%2C%20Los%20Altos%2C%20California%2C%20third%20edition&lr&hl=nl&pg=SA2-PA28#v=onepage&q=log&f=false

# %%
# define the frequency range in kHz
f = np.logspace(np.log10(0.001), np.log10(1000), 10000)
f_Hz = np.logspace(np.log10(1), np.log10(1000000), 10000)

# define shipping factor between 0 and 1
s = 1

# define the wind speed in m/s 
w = 5

print(f)
# Out:
# [1.00000000e-03 1.00138264e-03 1.00276720e-03 ... 9.97240436e+02
#  9.98619265e+02 1.00000000e+03]

# %%
# from [1/2] that got it from [3]

# formula for turbulance noise
logNt = 17 - 30 * np.log10(f)

# formula for shipping noise
logNs = 40 + 20 * (s - 0.5) + 26 * np.log10(f) - 60 * np.log10(f + 0.03)

# formula for wind-driven noise
logNw = 50 + 7.5 * w**(1/2) + 20 * np.log10(f) - 40 * np.log10(f + 0.4)

# formula for thermal noise
logNth = -15 + 20 * np.log10(f)

# %%
plt.figure(figsize=(10, 6))

# determine which array has the maximum value at each index
max_index = np.argmax([logNt, logNs, logNw, logNth], axis=0)

colors = ['orange', 'dodgerblue', 'blue', 'crimson', 'black']

for i in range(len(colors)):
    plt.plot(f_Hz[max_index == i], np.full_like(f_Hz[max_index == i], -81), color=colors[i], alpha=0.2, linewidth=10)

# plot the frequency and noise scales
plt.plot(f_Hz, logNt, color='orange', label='turbulence noise')
plt.plot(f_Hz, logNs, color='dodgerblue', label='shipping noise')
plt.plot(f_Hz, logNw, color='blue', label=f'wind noise (SS2)')
plt.plot(f_Hz, logNth, color='crimson', label='thermal noise')

plt.xscale('log')
plt.xlabel('Frequency [Hz]')
plt.xlim(10**0, 10**6)

plt.ylabel(f'PSD [dB re 1 $µPa^2$ per Hz]')
plt.ylim(-85, 125)

plt.title('Noise PSD')
plt.axvspan(500, 50000, color='gray', alpha=0.1, label="range of interest")

plt.grid(True, linestyle='--', color='gray', alpha=0.3)

plt.legend()
plt.savefig('Noise PSD.jpg')

plt.show()

# %% [markdown]
# Some of the same graphs that can be used for comparison:
#
# * https://www.researchgate.net/figure/The-PSD-of-ambient-noise-based-on-Wenz-model_fig4_318242002
# ![image.png](attachment:image.png)
#
# * https://www.researchgate.net/figure/Power-Spectral-Density-PSD-dB-re-Pascal-of-sample-acoustic-noise-sources-as_fig2_282381510
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Different Wind Speeds

# %%
# define the wind speed in m/s for different wind speeds
w_array = np.array([0, 0.29, 0.3, 1.5, 1.6, 3.3, 3.4, 5.4, 5.5, 7.9, 8.0, 10.7, 10.8, 13.8, 13.9, 17.1, 17.2, 20.7])

# calculate Nw for each of the wind speeds 
logNw_array = 50 + 7.5 * np.sqrt(w_array[:, np.newaxis]) + 20 * np.log10(f) - 40 * np.log10(f + 0.4)

# %%
plt.figure(figsize=(13, 10))

index_list = [0, 2, 4, 6, 8, 10, 12, 14]
color_list = ['blue', 'dodgerblue', 'mediumseagreen', 'yellowgreen', 'gold', 'orange', 'crimson', 'hotpink']
alpha_list = [0.02, 0.04 , 0.06, 0.08, 0.1, 0.12, 0.14, 0.16]
label_list = ['SS0', 'SS0.5', 'SS1', 'SS2', 'SS3', 'SS4', 'SS5', 'SS>6']

# plot the different wind speeds
for i in range(len(index_list)):
    index = index_list[i]
    plt.fill_between(f_Hz, logNw_array[index], logNw_array[index + 1], color=color_list[i], label=label_list[i], alpha=0.3)


plt.xscale('log')
plt.xlabel('frequency [Hz]')
plt.xlim(10**0, 10**6)

plt.ylabel('PSD [dB re µPa per Hz]')
plt.ylim(-85, 125)



plt.grid(True, linestyle='--', color='gray', alpha=0.3)

plt.legend()
plt.show()

# %% [markdown]
# # Neutrino PDS

# %%
# put in the neutrino energy in GeV (note: not the shower energy)
neutrino_energy = 1e11

# %%
# Neutrino 
def get_amplitude(neutrino_energy):
    """
    Generates the maximum amplitude in Pa of a neutrino with E = neutrino_energy at a distance of 1km from the source.
    """    
    # define the Bjorken-y variable
    y = 0.2
    
    # define the translation factor following Perkin (J. Perkin, ‘The acoustic detection of ultra high energy neutrinos,’ Ph.D. dissertation, TheUniversity of Sheffield, Jan. 2008)
    kv = 2.12 * 10**(-11)
    
    # calculate the corresponding amplitude of the original signal in Pa at 1km distance from the neutrino axis
    amplitude = y * kv * neutrino_energy
    
    return amplitude

def get_neutrino_sourcewaveform():
    """
    Generates a bipolar pulse with appropriate amp and period. 
    The function runs as bipolar_pulse(amp, pulse_width) where amp is in uPa, pulse_width is in seconds. 
    """
    
    fs = 500e5                          # sampling rate
    t = np.arange(0, 100e-6, 1/fs)      # time range to generate the pulse over 
    t = t-np.mean(t)                    # centre the time around the 0
    
    # get the amplitude of the bipolar pulse by Perkin's formula in Pa at 1 km distance
    p_norm_1km = get_amplitude(neutrino_energy)   
    p_norm = p_norm_1km * (10 / 4) 
    print(f'The amplitude of the signal is {round(p_norm_1km, 4)} Pa at 1 km distance.')
    print(f'The amplitude of the signal at the source is approximately {round(p_norm, 4)} Pa.')
    
    p_norm = p_norm_1km
    Pa2uPa = 1e6                        # conversion factor to micropascal
    amp = p_norm*Pa2uPa                 # microPa
    pulse_width = 80e-6                 # seconds
    
    # expression to generate a bipolar wave
    peak_pressure = -1 * amp * (t / (0.1*pulse_width)) * np.exp(-((t/(0.1*pulse_width))**2 - 1) / 2)
    
    # returns the time array, the waveform, and the sampling frequency
    return t, peak_pressure, fs

def nextPowerOf2(i):
    n = 1
    while n < i: 
        n *= 2
    return n

# %%
t, peak_pressure, fs = get_neutrino_sourcewaveform()

plt.figure(figsize=(13, 10))
plt.title(f'Neutrino with energy {neutrino_energy:.1e} GeV')
plt.plot(t*1e6, (peak_pressure), color='dodgerblue')
plt.xlabel('time [$\mu$s]')
plt.ylabel('peak pressure [mPa]')
plt.grid(True, linestyle='--', color='gray', alpha=0.3)
plt.show()
# Out:
# The amplitude of the signal is 0.424 Pa at 1 km distance.
# The amplitude of the signal at the source is approximately 1.06 Pa.

# %%
def get_PSD_neutrino():
    """
    Calculates and plots the fft of the waveform, the PSD of the waveform and the EPSDL of the waveform.
    """    
    
    # get the original neutrino waveform
    t, p_t, fs = get_neutrino_sourcewaveform()
    
    ###########################################################################################################################
    # DEFINE FREQUENCY DOMAIN AND POWER SPECTRAL DENSITY OF THE SIGNAL
    ###########################################################################################################################

    # The code calculates the next power of 2 for the length of the waveform 
    nfft = nextPowerOf2(len(t)) * 1000
    
    # Pad the waveform with zeros for FFT calculations
    p_t_e = np.pad(p_t, (0, nfft - len(p_t)), mode='constant')

    # Apply fft to the padded waveform to obtain the frequency domain representation
    X_f = np.fft.fft(p_t_e) 

    # Calculate frequency resolution
    df = fs / nfft
    print(f'The frequency resolution is {round(df, 2)} Hz.')
    
    # Generate frequency array corresponding to the FFT output
    # (In the context of signal processing and Fourier analysis, the maximum frequency is typically set to half of the sampling 
    # frequency (fs/2) due to the Nyquist-Shannon sampling theorem. This theorem states that in order to accurately reconstruct 
    #a continuous signal from its samples, the sampling frequency must be at least twice the maximum frequency present in the 
    # signal. However, here the max frequency is much higher than where we receive a signal, fs/500 is sufficient)
    freqs = np.arange(0, fs/500, df)
   
    # Slice the FFT output to make sure it is the same length as freqs (as freqs is 500 times smaller).
    # The end of the array is zero anyways due to the padding at the end.
    X_f = X_f[:len(freqs)]
 
    # plot the fft of the peak pressure
    #plt.figure(figsize=(13, 10))
    #plt.plot(freqs, X_f, color='dodgerblue')
    #plt.title(f'FFT of Peak Pressure ({neutrino_energy:.1e} GeV)')
    #plt.xlabel('frequency [Hz]')
    #plt.ylabel('fft [$\mu$Pa s]')
    #plt.xlim(0, max(freqs))
    #plt.grid(True, linestyle='--', color='gray', alpha=0.3)
    #plt.show()
    
    # calculate how many points are padded relatively
    padding_ratio = len(p_t_e) / len(p_t)
    
    # Calculate the normalized power spectral density with the formula described in the cell above
    X_f2 = abs(X_f)**2 / (2 * fs * padding_ratio)

    # plot the fft of the peak pressure
    #plt.figure(figsize=(13, 10))
    #plt.plot(freqs, X_f2, color='dodgerblue')
    #plt.title(f'PSD ({neutrino_energy:.1e} GeV)')
    #plt.xlabel('frequency [Hz]')
    #plt.ylabel('PSD [($\mu$Pa s)$^2$ / Hz]')
    #plt.xlim(0, max(freqs))
    #plt.grid(True, linestyle='--', color='gray', alpha=0.3)
    #plt.show()
    
    # The calculated ESL represents the average energy level of the waveform over its entire duration
    ESL = 10*np.log10(sum(p_t**2)/fs)   # in dB broadband energy source level
    
    # The calculated EPSDL represents the energy level distribution across different frequency components of the signal
    EPSDL = 10*np.log10(X_f2)        # in dB source energy spectral density level
    
    # plot the fft of the peak pressure
    #plt.figure(figsize=(13, 10))
    #plt.plot(freqs, EPSDL, color='dodgerblue')
    #plt.title(f'EPSDL ({neutrino_energy:.1e} GeV)')
    #plt.xlabel('frequency [Hz]')
    #plt.ylabel('Energy Level Distribution [dB re 1$\mu$Pa]')
    #plt.xscale('log')
    #plt.xlim(10**0, 10**5)
    #plt.ylim(-100, max(EPSDL)+10)
    #plt.grid(True, linestyle='--', color='gray', alpha=0.3)
    #plt.show()
   
    return freqs, EPSDL, df

freqs, EPSDL, df = get_PSD_neutrino()
# Out:
# The amplitude of the signal is 0.424 Pa at 1 km distance.
# The amplitude of the signal at the source is approximately 1.06 Pa.
# The frequency resolution is 6.1 Hz.

# %%
# find the index where f_Hz is equal or close to 10000
target_freq = 10000
index_closest = np.argmin(np.abs(f_Hz - target_freq))

print("Index where f_Hz is equal or close to 10000:", index_closest)
# Out:
# Index where f_Hz is equal or close to 10000: 6666

# %%
noise_sea_state_10000 = []

plt.figure(figsize=(10, 7))

# determine which array has the maximum value at each index
max_index = np.argmax([logNt, logNs, logNw, logNth], axis=0)

colors = ['orange', 'dodgerblue', 'blue', 'crimson', 'black']

#for i in range(len(colors)):
    #plt.plot(f_Hz[max_index == i], np.full_like(f_Hz[max_index == i], -56), color=colors[i], alpha=0.2, linewidth=10)

    
# determine the maximum wind speednoise in Tanganyika and Pylos
logNw_T = 50 + 7.5 * (7.8)**(1/2) + 20 * np.log10(f) - 40 * np.log10(f + 0.4)
logNw_P = 50 + 7.5 * (13.7)**(1/2) + 20 * np.log10(f) - 40 * np.log10(f + 0.4)  

# plot the frequency and noise scales
plt.plot(f_Hz, logNt, color='orange', label='turbulence noise')
plt.plot(f_Hz, logNs, color='dodgerblue', label='shipping noise')
plt.plot(f_Hz, logNth, color='crimson', label='thermal noise')
plt.plot(f_Hz, logNw_T, color='blue', linestyle='dashdot', label='max wind noise Tanganyika')
plt.plot(f_Hz, logNw_P, color='blue', linestyle='dashed', label='max wind noise Pylos')
plt.plot(freqs, EPSDL, color='black', label=f'$10^{{11}}$ GeV neutrino @1000 m')

# plot the different wind speeds
for i in range(len(index_list)):
    index = index_list[i]
    plt.fill_between(f_Hz, logNw_array[index], logNw_array[index + 1], color='blue', label=label_list[i], alpha=alpha_list[i])
    print(f'The value of the noise at a frequency of {target_freq} Hz is {logNw_array[index][index_closest]} Hz for sea state {label_list[i]}.')
    noise_sea_state_10000.append(logNw_array[index][6666])

  



plt.xscale('log')
plt.xlabel('Frequency [Hz]')
plt.xlim(10**0, 10**6)

plt.ylabel('PSD [dB re 1 $µPa^2$ per Hz]')
plt.ylim(-60, 160)

plt.grid(True, linestyle='--', color='gray', alpha=0.5)

# Create separate legends
handles1, labels1 = plt.gca().get_legend_handles_labels()  # Get handles and labels for the first legend

# Create handles and labels for the second legend
handles2, labels2 = [], []
for i in range(len(index_list)):
    handles2.append(plt.Rectangle((0, 0), 1, 1, fc="blue", alpha=alpha_list[i]))
    labels2.append(label_list[i])

# Plot the first legend
legend1 = plt.legend(handles1[:6], labels1[:6], loc='upper left')

# Plot the second legend
legend2 = plt.legend(handles2, labels2, loc='upper right')

plt.gca().add_artist(legend1)
plt.title("Complex Noise PSD")
plt.savefig('Complex Noise PSD.jpg')

plt.show()
# Out:
# The value of the noise at a frequency of 10000 Hz is 29.318666428048786 Hz for sea state SS0.
# The value of the noise at a frequency of 10000 Hz is 33.42658560933752 Hz for sea state SS0.5.
# The value of the noise at a frequency of 10000 Hz is 38.80549940855393 Hz for sea state SS1.
# The value of the noise at a frequency of 10000 Hz is 43.14798311398812 Hz for sea state SS2.
# The value of the noise at a frequency of 10000 Hz is 46.907725527386646 Hz for sea state SS3.
# The value of the noise at a frequency of 10000 Hz is 50.53186986364521 Hz for sea state SS4.
# The value of the noise at a frequency of 10000 Hz is 53.96618151578126 Hz for sea state SS5.
# The value of the noise at a frequency of 10000 Hz is 57.28069425150966 Hz for sea state SS>6.

# %%
print(noise_sea_state_10000)
# Out:
# [29.318666428048786, 33.42658560933752, 38.80549940855393, 43.14798311398812, 46.907725527386646, 50.53186986364521, 53.96618151578126, 57.28069425150966]

# %%
print(noise_sea_state_20000)
# Out:
# [23.631547596452776, 27.739466777741512, 33.11838057695792, 37.460864282392095, 41.22060669579062, 44.8447510320492, 48.27906268418525, 51.593575419913634, 54.73620962644435]
