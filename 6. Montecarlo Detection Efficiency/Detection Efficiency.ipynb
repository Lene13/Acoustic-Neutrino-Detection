# %% [markdown]
# The data is made with the:
#
# * LocID=2_runs=1000_NMin=20_RCan=1000_FHS =0_lines9
# * LocID=2_runs=1000_NMin=20_RCan=1000_FHS =0_lines11
# * LocID=2_runs=1000_NMin=20_RCan=1000_FHS =0_lines13
#
# I did this in order to check the bottom right plot on page 64 of Kevin's thesis.

# %% [markdown]
# The density (number of hydrophones) of hydrophones for the three detectors is as follows:
#
# *Cube*
# - 202.5 km$^{-3}$ (810)
# - 302.5 km$^{-3}$ (1210)
# - 422.5 km$^{-3}$ (1690)
#
# *Hexagon*
# - 201.38626339004415 km$^{-3}$ (799)
# - 317.3282923755514 km$^{-3}$ (1259)
# - 423.1884057971015 km$^{-3}$ (1679)
#
# *Cylinder*
# - 209.397998585938 km$^{-3}$ (840)
# - 311.6041645624078 km$^{-3}$ (1250)
# - 418.795997171876 km$^{-3}$ (1680)

# %% [markdown]
# # Cube

# %%
import matplotlib.pyplot as plt

# Define your points
points = [(9, 0.216), (11, 0.904), (13, 0.983)]
points_1200 = [(9, 0.152), (11, 0.788), (13, 0.947)]
points_1500 = [(9, 0.12), (11, 0.639), (13, 0.848)]
points_2000 = [(9, 0.042), (11, 0.432), (13, 0.725)]
points_3000 = [(9, 0.025), (11, 0.2), (13, 0.388)]

# Extract x and y coordinates
x_values = [point[0] for point in points]
y_values = [point[1] for point in points]

x_values_1200 = [point[0] for point in points_1200]
y_values_1200 = [point[1] for point in points_1200]

x_values_1500 = [point[0] for point in points_1500]
y_values_1500 = [point[1] for point in points_1500]

x_values_2000 = [point[0] for point in points_2000]
y_values_2000 = [point[1] for point in points_2000]

x_values_3000 = [point[0] for point in points_3000]
y_values_3000 = [point[1] for point in points_3000]

# Create a step plot
plt.step(x_values, y_values, where='post', linestyle='-', color='dodgerblue')
plt.step(x_values_1200, y_values_1200, where='post', linestyle='-', color='red')
plt.step(x_values_1500, y_values_1500, where='post', linestyle='-', color='orange')
plt.step(x_values_2000, y_values_2000, where='post', linestyle='-', color='gold')
plt.step(x_values_3000, y_values_3000, where='post', linestyle='-', color='blue')

# Add arrows and horizontal lines
for i in range(len(points) - 1):
    plt.plot(x_values[i], 0, 0, y_values[i], color='dodgerblue')
    plt.plot(x_values_1200[i], 0, 0, y_values_1200[i], color='red')
    plt.plot(x_values_1500[i], 0, 0, y_values_1500[i], color='orange')
    plt.plot(x_values_2000[i], 0, 0, y_values_2000[i], color='gold')
    plt.plot(x_values_3000[i], 0, 0, y_values_3000[i], color='blue')

    plt.plot(x_values[i], y_values[i], x_values[i + 1] - x_values[i], 0, color='dodgerblue')
    plt.plot(x_values_1200[i], y_values_1200[i], x_values_1200[i + 1] - x_values_1200[i], 0, color='red')
    plt.plot(x_values_1500[i], y_values_1500[i], x_values_1500[i + 1] - x_values_1500[i], 0, color='orange')
    plt.plot(x_values_2000[i], y_values_2000[i], x_values_2000[i + 1] - x_values_2000[i], 0, color='gold')
    plt.plot(x_values_3000[i], y_values_3000[i], x_values_3000[i + 1] - x_values_3000[i], 0, color='blue')

plt.vlines(x_values[0], 0, y_values[0], color='dodgerblue')
plt.vlines(13.5, 0, y_values[2], color='dodgerblue')
plt.hlines(y_values[2], 13, 13.5, color='dodgerblue', label='Rcan = 1000')

plt.vlines(x_values_1200[0], 0, y_values_1200[0], color='red')
plt.vlines(13.5, 0, y_values_1200[2], color='red')
plt.hlines(y_values_1200[2], 13, 13.5, color='red', label='Rcan = 1200')

plt.vlines(x_values_1500[0], 0, y_values_1500[0], color='orange')
plt.vlines(13.5, 0, y_values_1500[2], color='orange')
plt.hlines(y_values_1500[2], 13, 13.5, color='orange', label='Rcan = 1500')

plt.vlines(x_values_2000[0], 0, y_values_2000[0], color='gold')
plt.vlines(13.5, 0, y_values_2000[2], color='gold')
plt.hlines(y_values_2000[2], 13, 13.5, color='gold', label='Rcan = 2000')

plt.vlines(x_values_3000[0], 0, y_values_3000[0], color='blue')
plt.vlines(13.5, 0, y_values_3000[2], color='blue')
plt.hlines(y_values_3000[2], 13, 13.5, color='blue', label='Rcan = 3000')

plt.scatter(x_values, y_values, color='dodgerblue')
plt.scatter(x_values_1200, y_values_1200, color='red')
plt.scatter(x_values_1500, y_values_1500, color='orange')
plt.scatter(x_values_2000, y_values_2000, color='gold')
plt.scatter(x_values_3000, y_values_3000, color='blue')

plt.xlabel('Amount of Lines in x,y [-]')
plt.xlim(8.7, 13.8)
plt.ylabel('Detection Efficiency [-]')
plt.ylim(0, 1)

# set x ticks
plt.xticks([9, 11, 13])


plt.legend()
plt.title('Detection Efficiency vs Amount of Lines (Cylinder)')
plt.grid(True)
plt.savefig("Cube_Efficiency.jpg")
plt.show()

# %%
import matplotlib.pyplot as plt

# Define your points
points = [(9, 0.216), (11, 0.904), (13, 0.983)]
points_1200 = [(9, 0.152), (11, 0.788), (13, 0.947)]
points_1500 = [(9, 0.12), (11, 0.639), (13, 0.848)]
points_2000 = [(9, 0.042), (11, 0.432), (13, 0.725)]
points_3000 = [(9, 0.025), (11, 0.2), (13, 0.388)]

# Extract x and y coordinates
x_values = [point[0] for point in points]
y_values = [point[1] for point in points]

x_values_1200 = [point[0] for point in points_1200]
y_values_1200 = [point[1] for point in points_1200]

x_values_1500 = [point[0] for point in points_1500]
y_values_1500 = [point[1] for point in points_1500]

x_values_2000 = [point[0] for point in points_2000]
y_values_2000 = [point[1] for point in points_2000]

x_values_3000 = [point[0] for point in points_3000]
y_values_3000 = [point[1] for point in points_3000]

plt.figure(figsize=(7,4))

# Create a line plot
plt.plot(x_values, y_values, linestyle='-', color='dodgerblue', marker='o', label='Rbox = 1000')
plt.plot(x_values_1200, y_values_1200, linestyle='-', color='red', marker='o', label='Rbox = 1200')
plt.plot(x_values_1500, y_values_1500, linestyle='-', color='orange', marker='o', label='Rbox = 1500')
plt.plot(x_values_2000, y_values_2000, linestyle='-', color='gold', marker='o', label='Rbox = 2000')
plt.plot(x_values_3000, y_values_3000, linestyle='-', color='blue', marker='o', label='Rbox = 3000')

plt.scatter(x_values, y_values, color='dodgerblue')
plt.scatter(x_values_1200, y_values_1200, color='red')
plt.scatter(x_values_1500, y_values_1500, color='orange')
plt.scatter(x_values_2000, y_values_2000, color='gold')
plt.scatter(x_values_3000, y_values_3000, color='blue')

plt.xlabel('Detector Size [-]')
plt.xlim(8.7, 13.8)
plt.ylabel('Detection Efficiency [-]')
plt.ylim(0, 1)

# Set x ticks
plt.xticks([9, 11, 13],['S', 'M', 'L'])

plt.legend()
plt.title('Detection Efficiency vs Size (Cube)')
plt.grid(True, linestyle='--', color='gray', alpha=0.5)
plt.savefig("Cube_Efficiency.jpg")
plt.show()

# %% [markdown]
# # Hexagon

# %%
import matplotlib.pyplot as plt

# Define your points
points = [(9, 0.791), (11, 0.916), (13, 0.945)]
points_1200 = [(9, 0.74), (11, 0.862), (13, 0.896)]
points_1500 = [(9, 0.627), (11, 0.773), (13, 0.811)]
points_2000 = [(9, 0.445), (11, 0.613), (13, 0.676)]
points_3000 = [(9, 0.209), (11, 0.31), (13, 0.347)]

# Extract x and y coordinates
x_values = [point[0] for point in points]
y_values = [point[1] for point in points]

x_values_1200 = [point[0] for point in points_1200]
y_values_1200 = [point[1] for point in points_1200]

x_values_1500 = [point[0] for point in points_1500]
y_values_1500 = [point[1] for point in points_1500]

x_values_2000 = [point[0] for point in points_2000]
y_values_2000 = [point[1] for point in points_2000]

x_values_3000 = [point[0] for point in points_3000]
y_values_3000 = [point[1] for point in points_3000]

# Create a step plot
plt.step(x_values, y_values, where='post', linestyle='-', color='dodgerblue')
plt.step(x_values_1200, y_values_1200, where='post', linestyle='-', color='red')
plt.step(x_values_1500, y_values_1500, where='post', linestyle='-', color='orange')
plt.step(x_values_2000, y_values_2000, where='post', linestyle='-', color='gold')
plt.step(x_values_3000, y_values_3000, where='post', linestyle='-', color='blue')

# Add arrows and horizontal lines
for i in range(len(points) - 1):
    plt.plot(x_values[i], 0, 0, y_values[i], color='dodgerblue')
    plt.plot(x_values_1200[i], 0, 0, y_values_1200[i], color='red')
    plt.plot(x_values_1500[i], 0, 0, y_values_1500[i], color='orange')
    plt.plot(x_values_2000[i], 0, 0, y_values_2000[i], color='gold')
    plt.plot(x_values_3000[i], 0, 0, y_values_3000[i], color='blue')

    plt.plot(x_values[i], y_values[i], x_values[i + 1] - x_values[i], 0, color='dodgerblue')
    plt.plot(x_values_1200[i], y_values_1200[i], x_values_1200[i + 1] - x_values_1200[i], 0, color='red')
    plt.plot(x_values_1500[i], y_values_1500[i], x_values_1500[i + 1] - x_values_1500[i], 0, color='orange')
    plt.plot(x_values_2000[i], y_values_2000[i], x_values_2000[i + 1] - x_values_2000[i], 0, color='gold')
    plt.plot(x_values_3000[i], y_values_3000[i], x_values_3000[i + 1] - x_values_3000[i], 0, color='blue')

plt.vlines(x_values[0], 0, y_values[0], color='dodgerblue')
plt.vlines(13.5, 0, y_values[2], color='dodgerblue')
plt.hlines(y_values[2], 13, 13.5, color='dodgerblue', label='Rcan = 1000')

plt.vlines(x_values_1200[0], 0, y_values_1200[0], color='red')
plt.vlines(13.5, 0, y_values_1200[2], color='red')
plt.hlines(y_values_1200[2], 13, 13.5, color='red', label='Rcan = 1200')

plt.vlines(x_values_1500[0], 0, y_values_1500[0], color='orange')
plt.vlines(13.5, 0, y_values_1500[2], color='orange')
plt.hlines(y_values_1500[2], 13, 13.5, color='orange', label='Rcan = 1500')

plt.vlines(x_values_2000[0], 0, y_values_2000[0], color='gold')
plt.vlines(13.5, 0, y_values_2000[2], color='gold')
plt.hlines(y_values_2000[2], 13, 13.5, color='gold', label='Rcan = 2000')

plt.vlines(x_values_3000[0], 0, y_values_3000[0], color='blue')
plt.vlines(13.5, 0, y_values_3000[2], color='blue')
plt.hlines(y_values_3000[2], 13, 13.5, color='blue', label='Rcan = 3000')

plt.scatter(x_values, y_values, color='dodgerblue')
plt.scatter(x_values_1200, y_values_1200, color='red')
plt.scatter(x_values_1500, y_values_1500, color='orange')
plt.scatter(x_values_2000, y_values_2000, color='gold')
plt.scatter(x_values_3000, y_values_3000, color='blue')

plt.xlabel('Amount of Lines in x,y [-]')
plt.xlim(8.7, 13.8)
plt.ylabel('Detection Efficiency [-]')
plt.ylim(0, 1)

# set x ticks
plt.xticks([9, 11, 13])

plt.legend()
plt.title('Detection Efficiency vs Amount of Lines (Hexagon)')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Define your points
points = [(9, 0.543), (11, 0.94), (13, 0.98)]
points_1200 = [(9, 0.401), (11, 0.866), (13, 0.937)]
points_1500 = [(9, 0.265), (11, 0.757), (13, 0.862)]
points_2000 = [(9, 0.157), (11, 0.591), (13, 0.702)]
points_3000 = [(9, 0.095), (11, 0.299), (13, 0.37)]

# Extract x and y coordinates
x_values = [point[0] for point in points]
y_values = [point[1] for point in points]

x_values_1200 = [point[0] for point in points_1200]
y_values_1200 = [point[1] for point in points_1200]

x_values_1500 = [point[0] for point in points_1500]
y_values_1500 = [point[1] for point in points_1500]

x_values_2000 = [point[0] for point in points_2000]
y_values_2000 = [point[1] for point in points_2000]

x_values_3000 = [point[0] for point in points_3000]
y_values_3000 = [point[1] for point in points_3000]

plt.figure(figsize=(7,4))

# Create a line plot
plt.plot(x_values, y_values, linestyle='-', color='dodgerblue', marker='o', label='Rbox = 1000')
plt.plot(x_values_1200, y_values_1200, linestyle='-', color='red', marker='o', label='Rbox = 1200')
plt.plot(x_values_1500, y_values_1500, linestyle='-', color='orange', marker='o', label='Rbox = 1500')
plt.plot(x_values_2000, y_values_2000, linestyle='-', color='gold', marker='o', label='Rbox = 2000')
plt.plot(x_values_3000, y_values_3000, linestyle='-', color='blue', marker='o', label='Rbox = 3000')

plt.scatter(x_values, y_values, color='dodgerblue')
plt.scatter(x_values_1200, y_values_1200, color='red')
plt.scatter(x_values_1500, y_values_1500, color='orange')
plt.scatter(x_values_2000, y_values_2000, color='gold')
plt.scatter(x_values_3000, y_values_3000, color='blue')

plt.xlabel('Detector Size [-]')
plt.xlim(8.7, 13.8)
plt.ylabel('Detection Efficiency [-]')
plt.ylim(0, 1)

# Set x ticks
plt.xticks([9, 11, 13],['S', 'M', 'L'])

plt.legend()
plt.title('Detection Efficiency vs Size (Hexagon)')
plt.grid(True, linestyle='--', color='gray', alpha=0.5)
plt.savefig("Hexagon_Efficiency.jpg")
plt.show()

# %% [markdown]
# # Cylinder

# %%
import matplotlib.pyplot as plt

# Define your points
points = [(9, 0.237), (11, 0.931), (13, 0.983)]
points_1200 = [(9, 0.187), (11, 0.857), (13, 0.947)]
points_1500 = [(9, 0.121), (11, 0.742), (13, 0.854)]
points_2000 = [(9, 0.072), (11, 0.556), (13, 0.719)]
points_3000 = [(9, 0.038), (11, 0.286), (13, 0.394)]

# Extract x and y coordinates
x_values = [point[0] for point in points]
y_values = [point[1] for point in points]

x_values_1200 = [point[0] for point in points_1200]
y_values_1200 = [point[1] for point in points_1200]

x_values_1500 = [point[0] for point in points_1500]
y_values_1500 = [point[1] for point in points_1500]

x_values_2000 = [point[0] for point in points_2000]
y_values_2000 = [point[1] for point in points_2000]

x_values_3000 = [point[0] for point in points_3000]
y_values_3000 = [point[1] for point in points_3000]

# Create a step plot
plt.step(x_values, y_values, where='post', linestyle='-', color='dodgerblue')
plt.step(x_values_1200, y_values_1200, where='post', linestyle='-', color='red')
plt.step(x_values_1500, y_values_1500, where='post', linestyle='-', color='orange')
plt.step(x_values_2000, y_values_2000, where='post', linestyle='-', color='gold')
plt.step(x_values_3000, y_values_3000, where='post', linestyle='-', color='blue')

# Add arrows and horizontal lines
for i in range(len(points) - 1):
    plt.plot(x_values[i], 0, 0, y_values[i], color='dodgerblue')
    plt.plot(x_values_1200[i], 0, 0, y_values_1200[i], color='red')
    plt.plot(x_values_1500[i], 0, 0, y_values_1500[i], color='orange')
    plt.plot(x_values_2000[i], 0, 0, y_values_2000[i], color='gold')
    plt.plot(x_values_3000[i], 0, 0, y_values_3000[i], color='blue')

    plt.plot(x_values[i], y_values[i], x_values[i + 1] - x_values[i], 0, color='dodgerblue')
    plt.plot(x_values_1200[i], y_values_1200[i], x_values_1200[i + 1] - x_values_1200[i], 0, color='red')
    plt.plot(x_values_1500[i], y_values_1500[i], x_values_1500[i + 1] - x_values_1500[i], 0, color='orange')
    plt.plot(x_values_2000[i], y_values_2000[i], x_values_2000[i + 1] - x_values_2000[i], 0, color='gold')
    plt.plot(x_values_3000[i], y_values_3000[i], x_values_3000[i + 1] - x_values_3000[i], 0, color='blue')

plt.vlines(x_values[0], 0, y_values[0], color='dodgerblue')
plt.vlines(13.5, 0, y_values[2], color='dodgerblue')
plt.hlines(y_values[2], 13, 13.5, color='dodgerblue', label='Rcan = 1000')

plt.vlines(x_values_1200[0], 0, y_values_1200[0], color='red')
plt.vlines(13.5, 0, y_values_1200[2], color='red')
plt.hlines(y_values_1200[2], 13, 13.5, color='red', label='Rcan = 1200')

plt.vlines(x_values_1500[0], 0, y_values_1500[0], color='orange')
plt.vlines(13.5, 0, y_values_1500[2], color='orange')
plt.hlines(y_values_1500[2], 13, 13.5, color='orange', label='Rcan = 1500')

plt.vlines(x_values_2000[0], 0, y_values_2000[0], color='gold')
plt.vlines(13.5, 0, y_values_2000[2], color='gold')
plt.hlines(y_values_2000[2], 13, 13.5, color='gold', label='Rcan = 2000')

plt.vlines(x_values_3000[0], 0, y_values_3000[0], color='blue')
plt.vlines(13.5, 0, y_values_3000[2], color='blue')
plt.hlines(y_values_3000[2], 13, 13.5, color='blue', label='Rcan = 3000')

plt.scatter(x_values, y_values, color='dodgerblue')
plt.scatter(x_values_1200, y_values_1200, color='red')
plt.scatter(x_values_1500, y_values_1500, color='orange')
plt.scatter(x_values_2000, y_values_2000, color='gold')
plt.scatter(x_values_3000, y_values_3000, color='blue')

plt.xlabel('Amount of Lines in x,y [-]')
plt.xlim(8.7, 13.8)
plt.ylabel('Detection Efficiency [-]')
plt.ylim(0, 1)

# set x ticks
plt.xticks([9, 11, 13])

plt.legend()
plt.title('Detection Efficiency vs Amount of Lines (Cylinder)')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Define your points
points = [(9, 0.237), (11, 0.931), (13, 0.983)]
points_1200 = [(9, 0.187), (11, 0.857), (13, 0.947)]
points_1500 = [(9, 0.121), (11, 0.742), (13, 0.854)]
points_2000 = [(9, 0.072), (11, 0.556), (13, 0.719)]
points_3000 = [(9, 0.038), (11, 0.286), (13, 0.394)]

# Extract x and y coordinates
x_values = [point[0] for point in points]
y_values = [point[1] for point in points]

x_values_1200 = [point[0] for point in points_1200]
y_values_1200 = [point[1] for point in points_1200]

x_values_1500 = [point[0] for point in points_1500]
y_values_1500 = [point[1] for point in points_1500]

x_values_2000 = [point[0] for point in points_2000]
y_values_2000 = [point[1] for point in points_2000]

x_values_3000 = [point[0] for point in points_3000]
y_values_3000 = [point[1] for point in points_3000]

plt.figure(figsize=(7,4))
# Create a step plot
plt.plot(x_values, y_values, linestyle='-', color='dodgerblue', marker='o', label='Rbox = 1000')
plt.plot(x_values_1200, y_values_1200, linestyle='-', color='red', marker='o', label='Rbox = 1200')
plt.plot(x_values_1500, y_values_1500, linestyle='-', color='orange', marker='o', label='Rbox = 1500')
plt.plot(x_values_2000, y_values_2000, linestyle='-', color='gold', marker='o', label='Rbox = 2000')
plt.plot(x_values_3000, y_values_3000, linestyle='-', color='blue', marker='o', label='Rbox = 3000')

# Add scatter points for each step
plt.scatter(x_values, y_values, color='dodgerblue')
plt.scatter(x_values_1200, y_values_1200, color='red')
plt.scatter(x_values_1500, y_values_1500, color='orange')
plt.scatter(x_values_2000, y_values_2000, color='gold')
plt.scatter(x_values_3000, y_values_3000, color='blue')

# Set labels and limits
plt.xlabel('Detector Size [-]')
plt.xlim(8.7, 13.8)
plt.ylabel('Detection Efficiency [-]')
plt.ylim(0, 1)

# Set x ticks
plt.xticks([9, 11, 13],['S', 'M', 'L'])

# Add legend and grid
plt.legend()
plt.title('Detection Efficiency vs Size (Cylinder)')
plt.grid(True, linestyle='--', color='gray', alpha=0.5)

plt.savefig("Cylinder_configuration.jpg")
# Show plot
plt.show()

# %% [markdown]
# # Comparison Rcan = 1000

# %%
# Define your points
points = [(9, 0.216), (11, 0.904), (13, 0.983)]
points_1200 = [(9, 0.791), (11, 0.916), (13, 0.945)]
points_1500 = [(9, 0.237), (11, 0.931), (13, 0.983)]

# Extract x and y coordinates
x_values = [point[0] for point in points]
y_values = [point[1] for point in points]

x_values_1200 = [point[0] for point in points_1200]
y_values_1200 = [point[1] for point in points_1200]

x_values_1500 = [point[0] for point in points_1500]
y_values_1500 = [point[1] for point in points_1500]

# Create a step plot
plt.step(x_values, y_values, where='post', linestyle='-', color='dodgerblue')
plt.step(x_values_1200, y_values_1200, where='post', linestyle='-', color='red')
plt.step(x_values_1500, y_values_1500, where='post', linestyle='-', color='orange')

# Add arrows and horizontal lines
for i in range(len(points) - 1):
    plt.plot(x_values[i], 0, 0, y_values[i], color='dodgerblue')
    plt.plot(x_values_1200[i], 0, 0, y_values_1200[i], color='red')
    plt.plot(x_values_1500[i], 0, 0, y_values_1500[i], color='orange')

    plt.plot(x_values[i], y_values[i], x_values[i + 1] - x_values[i], 0, color='dodgerblue')
    plt.plot(x_values_1200[i], y_values_1200[i], x_values_1200[i + 1] - x_values_1200[i], 0, color='red')
    plt.plot(x_values_1500[i], y_values_1500[i], x_values_1500[i + 1] - x_values_1500[i], 0, color='orange')

plt.vlines(x_values[0], 0, y_values[0], color='dodgerblue')
plt.vlines(13.5, 0, y_values[2], color='dodgerblue')
plt.hlines(y_values[2], 13, 13.5, color='dodgerblue', label='Cube')

plt.vlines(x_values_1200[0], 0, y_values_1200[0], color='red')
plt.vlines(13.5, 0, y_values_1200[2], color='red')
plt.hlines(y_values_1200[2], 13, 13.5, color='red', label='Hexagon')

plt.vlines(x_values_1500[0], 0, y_values_1500[0], color='orange')
plt.vlines(13.5, 0, y_values_1500[2], color='orange')
plt.hlines(y_values_1500[2], 13, 13.5, color='orange', label='Cylinder')

plt.scatter(x_values, y_values, color='dodgerblue')
plt.scatter(x_values_1200, y_values_1200, color='red')
plt.scatter(x_values_1500, y_values_1500, color='orange')

plt.xlabel('Amount of Lines in x,y [-]')
plt.xlim(8.7, 13.8)
plt.ylabel('Detection Efficiency [-]')
plt.ylim(0, 1)

# set x ticks
plt.xticks([9, 11, 13])

plt.legend()
plt.title('Detection Efficiency vs Amount of Lines (RCan = 1000)')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(9,5))
# Define your points
Spoints_1000 = [(9, 0.216), (11, 0.904), (13, 0.983)]
Hpoints_1000 = [(9, 0.543), (11, 0.94), (13, 0.98)]           #[(9, 0.791), (11, 0.916), (13, 0.945)]
Cpoints_1000 = [(9, 0.237), (11, 0.931), (13, 0.983)]

Spoints_1200 = [(9, 0.152), (11, 0.788), (13, 0.947)]
Hpoints_1200 = [(9, 0.401), (11, 0.866), (13, 0.937)]         #[(9, 0.74), (11, 0.862), (13, 0.896)]
Cpoints_1200 = [(9, 0.187), (11, 0.857), (13, 0.947)]

Spoints_1500 = [(9, 0.12), (11, 0.639), (13, 0.848)]
Hpoints_1500 = [(9, 0.265), (11, 0.757), (13, 0.862)]         #[(9, 0.627), (11, 0.773), (13, 0.811)]
Cpoints_1500 = [(9, 0.121), (11, 0.742), (13, 0.854)]

Spoints_2000 = [(9, 0.042), (11, 0.432), (13, 0.725)]
Hpoints_2000 = [(9, 0.157), (11, 0.591), (13, 0.702)]         #[(9, 0.445), (11, 0.613), (13, 0.676)]
Cpoints_2000 = [(9, 0.072), (11, 0.556), (13, 0.719)]

Spoints_3000 = [(9, 0.025), (11, 0.2), (13, 0.388)]
Hpoints_3000 = [(9, 0.095), (11, 0.299), (13, 0.37)]           #[(9, 0.209), (11, 0.31), (13, 0.347)]
Cpoints_3000 = [(9, 0.038), (11, 0.286), (13, 0.394)]


# Extract x and y coordinates
Sx_values_1000 = [point[0] for point in Spoints_1000]
Sy_values_1000 = [point[1] for point in Spoints_1000]
Hx_values_1000 = [point[0] for point in Hpoints_1000]
Hy_values_1000 = [point[1] for point in Hpoints_1000]
Cx_values_1000 = [point[0] for point in Cpoints_1000]
Cy_values_1000 = [point[1] for point in Cpoints_1000]

Sx_values_1200 = [point[0] for point in Spoints_1200]
Sy_values_1200 = [point[1] for point in Spoints_1200]
Hx_values_1200 = [point[0] for point in Hpoints_1200]
Hy_values_1200 = [point[1] for point in Hpoints_1200]
Cx_values_1200 = [point[0] for point in Cpoints_1200]
Cy_values_1200 = [point[1] for point in Cpoints_1200]

Sx_values_1500 = [point[0] for point in Spoints_1500]
Sy_values_1500 = [point[1] for point in Spoints_1500]
Hx_values_1500 = [point[0] for point in Hpoints_1500]
Hy_values_1500 = [point[1] for point in Hpoints_1500]
Cx_values_1500 = [point[0] for point in Cpoints_1500]
Cy_values_1500 = [point[1] for point in Cpoints_1500]

Sx_values_2000 = [point[0] for point in Spoints_2000]
Sy_values_2000 = [point[1] for point in Spoints_2000]
Hx_values_2000 = [point[0] for point in Hpoints_2000]
Hy_values_2000 = [point[1] for point in Hpoints_2000]
Cx_values_2000 = [point[0] for point in Cpoints_2000]
Cy_values_2000 = [point[1] for point in Cpoints_2000]

Sx_values_3000 = [point[0] for point in Spoints_3000]
Sy_values_3000 = [point[1] for point in Spoints_3000]
Hx_values_3000 = [point[0] for point in Hpoints_3000]
Hy_values_3000 = [point[1] for point in Hpoints_3000]
Cx_values_3000 = [point[0] for point in Cpoints_3000]
Cy_values_3000 = [point[1] for point in Cpoints_3000]

# Create a line plot
plt.plot(Sx_values_1000, Sy_values_1000, linestyle='-', color='dodgerblue', markersize=4, marker='o', label='Cube          R=1000m')
plt.plot(Hx_values_1000, Hy_values_1000, linestyle='-', color='crimson', markersize=4, marker='o', label='Hexagon    R=1000m')
plt.plot(Cx_values_1000, Cy_values_1000, linestyle='-', color='orange', markersize=4, marker='o', label='Cylinder     R=1000m')

plt.plot(Sx_values_1200, Sy_values_1200, linestyle='dashdot', color='dodgerblue', markersize=4, marker='o', label='Cube          R=1200m')
plt.plot(Hx_values_1200, Hy_values_1200, linestyle='dashdot', color='crimson', markersize=4, marker='o', label='Hexagon    R=1200m')
plt.plot(Cx_values_1200, Cy_values_1200, linestyle='dashdot', color='orange', markersize=4, marker='o', label='Cylinder     R=1200m')

plt.plot(Sx_values_1500, Sy_values_1500, linestyle='dotted', color='dodgerblue', markersize=4, marker='o', label='Cube          R=1500m')
plt.plot(Hx_values_1500, Hy_values_1500, linestyle='dotted', color='crimson', markersize=4, marker='o', label='Hexagon    R=1500m')
plt.plot(Cx_values_1500, Cy_values_1500, linestyle='dotted', color='orange', markersize=4, marker='o', label='Cylinder     R=1500m')

plt.plot(Sx_values_2000, Sy_values_2000, linestyle='dashed', color='dodgerblue', markersize=4, marker='o', label='Cube          R=2000m')
plt.plot(Hx_values_2000, Hy_values_2000, linestyle='dashed', color='crimson', markersize=4, marker='o', label='Hexagon    R=2000m')
plt.plot(Cx_values_2000, Cy_values_2000, linestyle='dashed', color='orange', markersize=4, marker='o', label='Cylinder     R=2000m')

plt.plot(Sx_values_3000, Sy_values_3000, linestyle=(0, (3, 1, 1, 1, 1, 1)), color='dodgerblue', markersize=4, marker='o', label='Cube          R=3000m')
plt.plot(Hx_values_3000, Hy_values_3000, linestyle=(0, (3, 1, 1, 1, 1, 1)), color='crimson', markersize=4, marker='o', label='Hexagon    R=3000m')
plt.plot(Cx_values_3000, Cy_values_3000, linestyle=(0, (3, 1, 1, 1, 1, 1)), color='orange', markersize=4, marker='o', label='Cylinder     R=3000m')



plt.xlabel('Detector Size [-]')
plt.xlim(8.7, 15)
plt.ylabel('Detection Efficiency [-]')
plt.ylim(0, 1)

# Set x ticks
plt.xticks([9, 11, 13],['S', 'M', 'L'])

# Add legend and grid
plt.legend(loc="lower right")
plt.title('Detection Efficiency vs Detector Size')
plt.grid(True, linestyle='--', color='gray', alpha=0.5)

plt.savefig("Box.jpg")
# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(9,5))
# Define your points
Spoints_1000 = [(9, 0.216), (11, 0.904), (13, 0.983)]
Hpoints_1000 = [(9, 0.543), (11, 0.94), (13, 0.98)]           #[(9, 0.791), (11, 0.916), (13, 0.945)]
Cpoints_1000 = [(9, 0.237), (11, 0.931), (13, 0.983)]

Spoints_1200 = [(9, 0.152), (11, 0.788), (13, 0.947)]
Hpoints_1200 = [(9, 0.401), (11, 0.866), (13, 0.937)]         #[(9, 0.74), (11, 0.862), (13, 0.896)]
Cpoints_1200 = [(9, 0.187), (11, 0.857), (13, 0.947)]

Spoints_1500 = [(9, 0.12), (11, 0.639), (13, 0.848)]
Hpoints_1500 = [(9, 0.265), (11, 0.757), (13, 0.862)]         #[(9, 0.627), (11, 0.773), (13, 0.811)]
Cpoints_1500 = [(9, 0.121), (11, 0.742), (13, 0.854)]

Spoints_2000 = [(9, 0.042), (11, 0.432), (13, 0.725)]
Hpoints_2000 = [(9, 0.157), (11, 0.591), (13, 0.702)]         #[(9, 0.445), (11, 0.613), (13, 0.676)]
Cpoints_2000 = [(9, 0.072), (11, 0.556), (13, 0.719)]

Spoints_3000 = [(9, 0.025), (11, 0.2), (13, 0.388)]
Hpoints_3000 = [(9, 0.095), (11, 0.299), (13, 0.37)]           #[(9, 0.209), (11, 0.31), (13, 0.347)]
Cpoints_3000 = [(9, 0.038), (11, 0.286), (13, 0.394)]


# Extract x and y coordinates
Sx_values_1000 = [point[0] for point in Spoints_1000]
Sy_values_1000 = [point[1] for point in Spoints_1000]
Hx_values_1000 = [point[0] for point in Hpoints_1000]
Hy_values_1000 = [point[1] for point in Hpoints_1000]
Cx_values_1000 = [point[0] for point in Cpoints_1000]
Cy_values_1000 = [point[1] for point in Cpoints_1000]

Sx_values_1200 = [point[0] for point in Spoints_1200]
Sy_values_1200 = [point[1] for point in Spoints_1200]
Hx_values_1200 = [point[0] for point in Hpoints_1200]
Hy_values_1200 = [point[1] for point in Hpoints_1200]
Cx_values_1200 = [point[0] for point in Cpoints_1200]
Cy_values_1200 = [point[1] for point in Cpoints_1200]

Sx_values_1500 = [point[0] for point in Spoints_1500]
Sy_values_1500 = [point[1] for point in Spoints_1500]
Hx_values_1500 = [point[0] for point in Hpoints_1500]
Hy_values_1500 = [point[1] for point in Hpoints_1500]
Cx_values_1500 = [point[0] for point in Cpoints_1500]
Cy_values_1500 = [point[1] for point in Cpoints_1500]

Sx_values_2000 = [point[0] for point in Spoints_2000]
Sy_values_2000 = [point[1] for point in Spoints_2000]
Hx_values_2000 = [point[0] for point in Hpoints_2000]
Hy_values_2000 = [point[1] for point in Hpoints_2000]
Cx_values_2000 = [point[0] for point in Cpoints_2000]
Cy_values_2000 = [point[1] for point in Cpoints_2000]

Sx_values_3000 = [point[0] for point in Spoints_3000]
Sy_values_3000 = [point[1] for point in Spoints_3000]
Hx_values_3000 = [point[0] for point in Hpoints_3000]
Hy_values_3000 = [point[1] for point in Hpoints_3000]
Cx_values_3000 = [point[0] for point in Cpoints_3000]
Cy_values_3000 = [point[1] for point in Cpoints_3000]

# Create a line plot
plt.plot(Sx_values_1000, Sy_values_1000, linestyle='dotted', color='dodgerblue', markersize=4, marker='o', label='Cube          R=1000m')
plt.plot(Hx_values_1000, Hy_values_1000, linestyle='-', color='dodgerblue', markersize=4, marker='o', label='Hexagon    R=1000m')
plt.plot(Cx_values_1000, Cy_values_1000, linestyle='dashed', color='dodgerblue', markersize=4, marker='o', label='Cylinder     R=1000m')

plt.plot(Sx_values_1200, Sy_values_1200, linestyle='dotted', color='crimson', markersize=4, marker='o', label='Cube          R=1200m')
plt.plot(Hx_values_1200, Hy_values_1200, linestyle='-', color='crimson', markersize=4, marker='o', label='Hexagon    R=1200m')
plt.plot(Cx_values_1200, Cy_values_1200, linestyle='dashed', color='crimson', markersize=4, marker='o', label='Cylinder     R=1200m')

plt.plot(Sx_values_1500, Sy_values_1500, linestyle='dotted', color='orange', markersize=4, marker='o', label='Cube          R=1500m')
plt.plot(Hx_values_1500, Hy_values_1500, linestyle='-', color='orange', markersize=4, marker='o', label='Hexagon    R=1500m')
plt.plot(Cx_values_1500, Cy_values_1500, linestyle='dashed', color='orange', markersize=4, marker='o', label='Cylinder     R=1500m')

plt.plot(Sx_values_2000, Sy_values_2000, linestyle='dotted', color='blue', markersize=4, marker='o', label='Cube          R=2000m')
plt.plot(Hx_values_2000, Hy_values_2000, linestyle='-', color='blue', markersize=4, marker='o', label='Hexagon    R=2000m')
plt.plot(Cx_values_2000, Cy_values_2000, linestyle='dashed', color='blue', markersize=4, marker='o', label='Cylinder     R=2000m')

plt.plot(Sx_values_3000, Sy_values_3000, linestyle='dotted', color='gold', markersize=4, marker='o', label='Cube          R=3000m')
plt.plot(Hx_values_3000, Hy_values_3000, linestyle='-', color='gold', markersize=4, marker='o', label='Hexagon    R=3000m')
plt.plot(Cx_values_3000, Cy_values_3000, linestyle='dashed', color='gold', markersize=4, marker='o', label='Cylinder     R=3000m')



plt.xlabel('Detector Size [-]')
plt.xlim(8.7, 15)
plt.ylabel('Detection Efficiency [-]')
plt.ylim(0, 1)

# Set x ticks
plt.xticks([9, 11, 13],['S', 'M', 'L'])

# Add legend and grid
plt.legend(loc="lower right")
plt.title('Detection Efficiency vs Detector Size')
plt.grid(True, linestyle='--', color='gray', alpha=0.5)

plt.savefig("Box.jpg")
# Show plot
plt.show()

# %% [markdown]
# # Comparison Rcan = 1200

# %%
# Define your points
points = [(9, 0.152), (11, 0.788), (13, 0.947)]
points_1200 = [(9, 0.74), (11, 0.862), (13, 0.896)]
points_1500 = [(9, 0.187), (11, 0.857), (13, 0.947)]


# Extract x and y coordinates
x_values = [point[0] for point in points]
y_values = [point[1] for point in points]

x_values_1200 = [point[0] for point in points_1200]
y_values_1200 = [point[1] for point in points_1200]

x_values_1500 = [point[0] for point in points_1500]
y_values_1500 = [point[1] for point in points_1500]

# Create a step plot
plt.step(x_values, y_values, where='post', linestyle='-', color='dodgerblue')
plt.step(x_values_1200, y_values_1200, where='post', linestyle='-', color='red')
plt.step(x_values_1500, y_values_1500, where='post', linestyle='-', color='orange')

# Add arrows and horizontal lines
for i in range(len(points) - 1):
    plt.plot(x_values[i], 0, 0, y_values[i], color='dodgerblue')
    plt.plot(x_values_1200[i], 0, 0, y_values_1200[i], color='red')
    plt.plot(x_values_1500[i], 0, 0, y_values_1500[i], color='orange')

    plt.plot(x_values[i], y_values[i], x_values[i + 1] - x_values[i], 0, color='dodgerblue')
    plt.plot(x_values_1200[i], y_values_1200[i], x_values_1200[i + 1] - x_values_1200[i], 0, color='red')
    plt.plot(x_values_1500[i], y_values_1500[i], x_values_1500[i + 1] - x_values_1500[i], 0, color='orange')

plt.vlines(x_values[0], 0, y_values[0], color='dodgerblue')
plt.vlines(13.5, 0, y_values[2], color='dodgerblue')
plt.hlines(y_values[2], 13, 13.5, color='dodgerblue', label='Cube')

plt.vlines(x_values_1200[0], 0, y_values_1200[0], color='red')
plt.vlines(13.5, 0, y_values_1200[2], color='red')
plt.hlines(y_values_1200[2], 13, 13.5, color='red', label='Hexagon')

plt.vlines(x_values_1500[0], 0, y_values_1500[0], color='orange')
plt.vlines(13.5, 0, y_values_1500[2], color='orange')
plt.hlines(y_values_1500[2], 13, 13.5, color='orange', label='Cylinder')

plt.scatter(x_values, y_values, color='dodgerblue')
plt.scatter(x_values_1200, y_values_1200, color='red')
plt.scatter(x_values_1500, y_values_1500, color='orange')

plt.xlabel('Amount of Lines in x,y [-]')
plt.xlim(8.7, 13.8)
plt.ylabel('Detection Efficiency [-]')
plt.ylim(0, 1)

# set x ticks
plt.xticks([9, 11, 13])

plt.legend()
plt.title('Detection Efficiency vs Amount of Lines (RCan = 1200)')
plt.grid(True)
plt.show()

# %% [markdown]
# # Comparison Rcan = 1500

# %%
# Define your points
points = [(9, 0.12), (11, 0.639), (13, 0.848)]
points_1200 = [(9, 0.627), (11, 0.773), (13, 0.811)]
points_1500 = [(9, 0.121), (11, 0.742), (13, 0.854)]

# Extract x and y coordinates
x_values = [point[0] for point in points]
y_values = [point[1] for point in points]

x_values_1200 = [point[0] for point in points_1200]
y_values_1200 = [point[1] for point in points_1200]

x_values_1500 = [point[0] for point in points_1500]
y_values_1500 = [point[1] for point in points_1500]

# Create a step plot
plt.step(x_values, y_values, where='post', linestyle='-', color='dodgerblue')
plt.step(x_values_1200, y_values_1200, where='post', linestyle='-', color='red')
plt.step(x_values_1500, y_values_1500, where='post', linestyle='-', color='orange')

# Add arrows and horizontal lines
for i in range(len(points) - 1):
    plt.plot(x_values[i], 0, 0, y_values[i], color='dodgerblue')
    plt.plot(x_values_1200[i], 0, 0, y_values_1200[i], color='red')
    plt.plot(x_values_1500[i], 0, 0, y_values_1500[i], color='orange')

    plt.plot(x_values[i], y_values[i], x_values[i + 1] - x_values[i], 0, color='dodgerblue')
    plt.plot(x_values_1200[i], y_values_1200[i], x_values_1200[i + 1] - x_values_1200[i], 0, color='red')
    plt.plot(x_values_1500[i], y_values_1500[i], x_values_1500[i + 1] - x_values_1500[i], 0, color='orange')

plt.vlines(x_values[0], 0, y_values[0], color='dodgerblue')
plt.vlines(13.5, 0, y_values[2], color='dodgerblue')
plt.hlines(y_values[2], 13, 13.5, color='dodgerblue', label='Cube')

plt.vlines(x_values_1200[0], 0, y_values_1200[0], color='red')
plt.vlines(13.5, 0, y_values_1200[2], color='red')
plt.hlines(y_values_1200[2], 13, 13.5, color='red', label='Hexagon')

plt.vlines(x_values_1500[0], 0, y_values_1500[0], color='orange')
plt.vlines(13.5, 0, y_values_1500[2], color='orange')
plt.hlines(y_values_1500[2], 13, 13.5, color='orange', label='Cylinder')

plt.scatter(x_values, y_values, color='dodgerblue')
plt.scatter(x_values_1200, y_values_1200, color='red')
plt.scatter(x_values_1500, y_values_1500, color='orange')

plt.xlabel('Amount of Lines in x,y [-]')
plt.xlim(8.7, 13.8)
plt.ylabel('Detection Efficiency [-]')
plt.ylim(0, 1)

# set x ticks
plt.xticks([9, 11, 13])

plt.legend()
plt.title('Detection Efficiency vs Amount of Lines (RCan = 1500)')
plt.grid(True)
plt.show()

# %% [markdown]
# # Comparison Rcan = 2000

# %%
# Define your points
points = [(9, 0.042), (11, 0.432), (13, 0.725)]
points_1200 = [(9, 0.445), (11, 0.613), (13, 0.676)]
points_1500 = [(9, 0.072), (11, 0.556), (13, 0.719)]

# Extract x and y coordinates
x_values = [point[0] for point in points]
y_values = [point[1] for point in points]

x_values_1200 = [point[0] for point in points_1200]
y_values_1200 = [point[1] for point in points_1200]

x_values_1500 = [point[0] for point in points_1500]
y_values_1500 = [point[1] for point in points_1500]

# Create a step plot
plt.step(x_values, y_values, where='post', linestyle='-', color='dodgerblue')
plt.step(x_values_1200, y_values_1200, where='post', linestyle='-', color='red')
plt.step(x_values_1500, y_values_1500, where='post', linestyle='-', color='orange')

# Add arrows and horizontal lines
for i in range(len(points) - 1):
    plt.plot(x_values[i], 0, 0, y_values[i], color='dodgerblue')
    plt.plot(x_values_1200[i], 0, 0, y_values_1200[i], color='red')
    plt.plot(x_values_1500[i], 0, 0, y_values_1500[i], color='orange')

    plt.plot(x_values[i], y_values[i], x_values[i + 1] - x_values[i], 0, color='dodgerblue')
    plt.plot(x_values_1200[i], y_values_1200[i], x_values_1200[i + 1] - x_values_1200[i], 0, color='red')
    plt.plot(x_values_1500[i], y_values_1500[i], x_values_1500[i + 1] - x_values_1500[i], 0, color='orange')

plt.vlines(x_values[0], 0, y_values[0], color='dodgerblue')
plt.vlines(13.5, 0, y_values[2], color='dodgerblue')
plt.hlines(y_values[2], 13, 13.5, color='dodgerblue', label='Cube')

plt.vlines(x_values_1200[0], 0, y_values_1200[0], color='red')
plt.vlines(13.5, 0, y_values_1200[2], color='red')
plt.hlines(y_values_1200[2], 13, 13.5, color='red', label='Hexagon')

plt.vlines(x_values_1500[0], 0, y_values_1500[0], color='orange')
plt.vlines(13.5, 0, y_values_1500[2], color='orange')
plt.hlines(y_values_1500[2], 13, 13.5, color='orange', label='Cylinder')

plt.scatter(x_values, y_values, color='dodgerblue')
plt.scatter(x_values_1200, y_values_1200, color='red')
plt.scatter(x_values_1500, y_values_1500, color='orange')

plt.xlabel('Amount of Lines in x,y [-]')
plt.xlim(8.7, 13.8)
plt.ylabel('Detection Efficiency [-]')
plt.ylim(0, 1)

# set x ticks
plt.xticks([9, 11, 13])

plt.legend()
plt.title('Detection Efficiency vs Amount of Lines (RCan = 2000)')
plt.grid(True)
plt.show()

# %% [markdown]
# # Comparison Rcan = 3000

# %%
# Define your points
points = [(9, 0.025), (11, 0.2), (13, 0.388)]
points_1200 = [(9, 0.209), (11, 0.31), (13, 0.347)]
points_1500 = [(9, 0.038), (11, 0.286), (13, 0.394)]

# Extract x and y coordinates
x_values = [point[0] for point in points]
y_values = [point[1] for point in points]

x_values_1200 = [point[0] for point in points_1200]
y_values_1200 = [point[1] for point in points_1200]

x_values_1500 = [point[0] for point in points_1500]
y_values_1500 = [point[1] for point in points_1500]

# Create a step plot
plt.step(x_values, y_values, where='post', linestyle='-', color='dodgerblue')
plt.step(x_values_1200, y_values_1200, where='post', linestyle='-', color='red')
plt.step(x_values_1500, y_values_1500, where='post', linestyle='-', color='orange')

# Add arrows and horizontal lines
for i in range(len(points) - 1):
    plt.plot(x_values[i], 0, 0, y_values[i], color='dodgerblue')
    plt.plot(x_values_1200[i], 0, 0, y_values_1200[i], color='red')
    plt.plot(x_values_1500[i], 0, 0, y_values_1500[i], color='orange')

    plt.plot(x_values[i], y_values[i], x_values[i + 1] - x_values[i], 0, color='dodgerblue')
    plt.plot(x_values_1200[i], y_values_1200[i], x_values_1200[i + 1] - x_values_1200[i], 0, color='red')
    plt.plot(x_values_1500[i], y_values_1500[i], x_values_1500[i + 1] - x_values_1500[i], 0, color='orange')

plt.vlines(x_values[0], 0, y_values[0], color='dodgerblue')
plt.vlines(13.5, 0, y_values[2], color='dodgerblue')
plt.hlines(y_values[2], 13, 13.5, color='dodgerblue', label='Cube')

plt.vlines(x_values_1200[0], 0, y_values_1200[0], color='red')
plt.vlines(13.5, 0, y_values_1200[2], color='red')
plt.hlines(y_values_1200[2], 13, 13.5, color='red', label='Hexagon')

plt.vlines(x_values_1500[0], 0, y_values_1500[0], color='orange')
plt.vlines(13.5, 0, y_values_1500[2], color='orange')
plt.hlines(y_values_1500[2], 13, 13.5, color='orange', label='Cylinder')

plt.scatter(x_values, y_values, color='dodgerblue')
plt.scatter(x_values_1200, y_values_1200, color='red')
plt.scatter(x_values_1500, y_values_1500, color='orange')

plt.xlabel('Amount of Lines in x,y [-]')
plt.xlim(8.7, 13.8)
plt.ylabel('Detection Efficiency [-]')
plt.ylim(0, 1)

# set x ticks
plt.xticks([9, 11, 13])

plt.legend()
plt.title('Detection Efficiency vs Amount of Lines (RCan = 3000)')
plt.grid(True)
plt.show()
